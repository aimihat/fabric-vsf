# %%
import pickle
with open("/Users/aimihat/Desktop/Thesis/fabric-vsf/logs/demos-2020-10-26-23-05-pol-video_random-seed-22-tier0-model-NA-cost-NA_epis_1.pkl", 'rb') as f:
    data = pickle.load(f)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(data[0]['interm_obs'][0][19])

# %%
# Out:
# 56

# %%
data[0]
# Out:
# defaultdict(list,
#             {'obs': [array([[[64, 64, 64],
#                       [64, 64, 64],
#                       [64, 64, 64],
#                       ...,
#                       [64, 64, 64],
#                       [64, 64, 64],
#                       [64, 64, 64]],
#
#                      [[64, 64, 64],
#                       [64, 64, 64],
#                       [64, 64, 64],
#                       ...,
#                       [64, 64, 64],
#                       [64, 64, 64],
#                       [64, 64, 64]],
#
#                      [[64, 64, 64],
#                       [64, 64, 64],
#                       [64, 64, 64],
#                       ...,
#                       [64, 64, 64],
#                       [64, 64, 64],
#                       [64, 64, 64]],
#
#                      ...,
#
#                      [[64, 64, 64],
#                       [64, 64, 64],
#                       [64, 64, 64],
#                       ...,
# ...
